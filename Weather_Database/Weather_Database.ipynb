# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
# Import the API key.
from config import weather_api_key
# print(weather_api_key)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 782

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | la ciotat
# Processing Record 9 of Set 1 | bahia blanca
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | sturgis
# Processing Record 12 of Set 1 | grand forks
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | bustamante
# Processing Record 16 of Set 1 | mattru
# Processing Record 17 of Set 1 | srednekolymsk
# Processing Record 18 of Set 1 | progreso
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | kavaratti
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | asau
# Processing Record 23 of Set 1 | baoding
# Processing Record 24 of Set 1 | saint-augustin
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | rafsanjan
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | kruisfontein
# Processing Record 30 of Set 1 | lagoa
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | matsanga
# City not found. Skipping...
# Processing Record 34 of Set 1 | brae
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | albert lea
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | senno
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | balkanabat
# Processing Record 41 of Set 1 | ancud
# Processing Record 42 of Set 1 | cocentaina
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | coleraine
# Processing Record 46 of Set 1 | goshen
# Processing Record 47 of Set 1 | codrington
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | san juan bautista
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 2 | hobyo
# Processing Record 4 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 2 | yar-sale
# Processing Record 6 of Set 2 | panorama
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | korla
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | puntarenas
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | collie
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | griffith
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | airai
# Processing Record 21 of Set 2 | praya
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | tilichiki
# Processing Record 24 of Set 2 | launceston
# Processing Record 25 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | batagay
# Processing Record 28 of Set 2 | torbay
# Processing Record 29 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | grindavik
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | baghdad
# Processing Record 35 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | pochutla
# Processing Record 38 of Set 2 | saldanha
# Processing Record 39 of Set 2 | necochea
# Processing Record 40 of Set 2 | tasiilaq
# Processing Record 41 of Set 2 | deputatskiy
# Processing Record 42 of Set 2 | severo-kurilsk
# Processing Record 43 of Set 2 | iqaluit
# Processing Record 44 of Set 2 | sao gabriel da cachoeira
# Processing Record 45 of Set 2 | hasaki
# Processing Record 46 of Set 2 | hambantota
# Processing Record 47 of Set 2 | salalah
# Processing Record 48 of Set 2 | victoria
# Processing Record 49 of Set 2 | cidreira
# Processing Record 50 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 3 | goderich
# Processing Record 2 of Set 3 | kalmunai
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | sur
# Processing Record 5 of Set 3 | araouane
# Processing Record 6 of Set 3 | katsuura
# Processing Record 7 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 3 | yaan
# Processing Record 9 of Set 3 | hithadhoo
# Processing Record 10 of Set 3 | arman
# Processing Record 11 of Set 3 | luena
# Processing Record 12 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 3 | vila do maio
# Processing Record 14 of Set 3 | novyy urengoy
# Processing Record 15 of Set 3 | neftcala
# Processing Record 16 of Set 3 | zhicheng
# Processing Record 17 of Set 3 | vanimo
# Processing Record 18 of Set 3 | tezu
# Processing Record 19 of Set 3 | luderitz
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 3 | nuuk
# Processing Record 24 of Set 3 | phnum penh
# City not found. Skipping...
# Processing Record 25 of Set 3 | sioux lookout
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | yulara
# Processing Record 28 of Set 3 | weymouth
# Processing Record 29 of Set 3 | naze
# Processing Record 30 of Set 3 | ferkessedougou
# Processing Record 31 of Set 3 | aklavik
# Processing Record 32 of Set 3 | keningau
# Processing Record 33 of Set 3 | axtla
# City not found. Skipping...
# Processing Record 34 of Set 3 | xining
# Processing Record 35 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | balezino
# Processing Record 38 of Set 3 | coracao de jesus
# Processing Record 39 of Set 3 | tlaxiaco
# City not found. Skipping...
# Processing Record 40 of Set 3 | dikson
# Processing Record 41 of Set 3 | hokitika
# Processing Record 42 of Set 3 | manokwari
# Processing Record 43 of Set 3 | san quintin
# Processing Record 44 of Set 3 | bubaque
# Processing Record 45 of Set 3 | caravelas
# Processing Record 46 of Set 3 | vaitape
# Processing Record 47 of Set 3 | banmo
# City not found. Skipping...
# Processing Record 48 of Set 3 | nanae
# Processing Record 49 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 3 | chokurdakh
# Processing Record 1 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 2 of Set 4 | ghindari
# Processing Record 3 of Set 4 | alice springs
# Processing Record 4 of Set 4 | berlevag
# Processing Record 5 of Set 4 | roma
# Processing Record 6 of Set 4 | ilovlya
# Processing Record 7 of Set 4 | zarichne
# Processing Record 8 of Set 4 | tanjong malim
# City not found. Skipping...
# Processing Record 9 of Set 4 | jining
# Processing Record 10 of Set 4 | tefe
# Processing Record 11 of Set 4 | arona
# Processing Record 12 of Set 4 | brufut
# Processing Record 13 of Set 4 | manaure
# Processing Record 14 of Set 4 | san rafael
# Processing Record 15 of Set 4 | carutapera
# Processing Record 16 of Set 4 | acapulco
# Processing Record 17 of Set 4 | teya
# Processing Record 18 of Set 4 | half moon bay
# Processing Record 19 of Set 4 | kirkenaer
# Processing Record 20 of Set 4 | bluff
# Processing Record 21 of Set 4 | ribeira brava
# Processing Record 22 of Set 4 | saint-philippe
# Processing Record 23 of Set 4 | bulaevo
# Processing Record 24 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 4 | eshowe
# Processing Record 26 of Set 4 | los llanos de aridane
# Processing Record 27 of Set 4 | byron bay
# Processing Record 28 of Set 4 | andenes
# Processing Record 29 of Set 4 | college
# Processing Record 30 of Set 4 | sars
# Processing Record 31 of Set 4 | kutum
# Processing Record 32 of Set 4 | conceicao do araguaia
# Processing Record 33 of Set 4 | tuktoyaktuk
# Processing Record 34 of Set 4 | port blair
# Processing Record 35 of Set 4 | kulhudhuffushi
# Processing Record 36 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 4 | ribeira grande
# Processing Record 38 of Set 4 | sao filipe
# Processing Record 39 of Set 4 | boyolangu
# Processing Record 40 of Set 4 | nikolskoye
# Processing Record 41 of Set 4 | kavieng
# Processing Record 42 of Set 4 | behshahr
# Processing Record 43 of Set 4 | bairiki
# Processing Record 44 of Set 4 | saint anthony
# Processing Record 45 of Set 4 | todos santos
# Processing Record 46 of Set 4 | sept-iles
# Processing Record 47 of Set 4 | sucre
# Processing Record 48 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 49 of Set 4 | tommot
# Processing Record 50 of Set 4 | maragua
# Processing Record 1 of Set 5 | sainte-maxime
# Processing Record 2 of Set 5 | bengkulu
# Processing Record 3 of Set 5 | bethel
# Processing Record 4 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 5 | champerico
# Processing Record 6 of Set 5 | richards bay
# Processing Record 7 of Set 5 | tuatapere
# Processing Record 8 of Set 5 | sobolevo
# Processing Record 9 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 5 | manzil tamim
# City not found. Skipping...
# Processing Record 11 of Set 5 | la seyne-sur-mer
# Processing Record 12 of Set 5 | olafsvik
# Processing Record 13 of Set 5 | lebu
# Processing Record 14 of Set 5 | mvuma
# Processing Record 15 of Set 5 | nizhniy bestyakh
# Processing Record 16 of Set 5 | tigil
# Processing Record 17 of Set 5 | cornwall
# Processing Record 18 of Set 5 | kaitangata
# Processing Record 19 of Set 5 | pafos
# Processing Record 20 of Set 5 | vaxjo
# Processing Record 21 of Set 5 | autun
# Processing Record 22 of Set 5 | mount gambier
# Processing Record 23 of Set 5 | clyde river
# Processing Record 24 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 5 | fairbanks
# Processing Record 26 of Set 5 | zhezkazgan
# Processing Record 27 of Set 5 | alta floresta
# Processing Record 28 of Set 5 | feltre
# Processing Record 29 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 5 | karacabey
# Processing Record 31 of Set 5 | singkang
# Processing Record 32 of Set 5 | ehingen
# Processing Record 33 of Set 5 | burnie
# Processing Record 34 of Set 5 | klaksvik
# Processing Record 35 of Set 5 | souillac
# Processing Record 36 of Set 5 | rudnichnyy
# Processing Record 37 of Set 5 | skibbereen
# Processing Record 38 of Set 5 | faya
# Processing Record 39 of Set 5 | pemba
# Processing Record 40 of Set 5 | hirara
# Processing Record 41 of Set 5 | wahiawa
# Processing Record 42 of Set 5 | esperance
# Processing Record 43 of Set 5 | thinadhoo
# Processing Record 44 of Set 5 | saint george
# Processing Record 45 of Set 5 | anadyr
# Processing Record 46 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 5 | norrkoping
# Processing Record 48 of Set 5 | greenwood
# Processing Record 49 of Set 5 | monte santo
# Processing Record 50 of Set 5 | vardo
# Processing Record 1 of Set 6 | andarab
# City not found. Skipping...
# Processing Record 2 of Set 6 | meulaboh
# Processing Record 3 of Set 6 | paracatu
# Processing Record 4 of Set 6 | jiwani
# Processing Record 5 of Set 6 | port hedland
# Processing Record 6 of Set 6 | lunino
# Processing Record 7 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 6 | leningradskiy
# Processing Record 9 of Set 6 | portland
# Processing Record 10 of Set 6 | lamu
# Processing Record 11 of Set 6 | coahuayana
# Processing Record 12 of Set 6 | sitka
# Processing Record 13 of Set 6 | khromtau
# Processing Record 14 of Set 6 | mayo
# Processing Record 15 of Set 6 | taoudenni
# Processing Record 16 of Set 6 | adre
# Processing Record 17 of Set 6 | monzon
# Processing Record 18 of Set 6 | marmora
# Processing Record 19 of Set 6 | emerald
# Processing Record 20 of Set 6 | vesoul
# Processing Record 21 of Set 6 | bandarbeyla
# Processing Record 22 of Set 6 | khani
# Processing Record 23 of Set 6 | jalu
# Processing Record 24 of Set 6 | norman wells
# Processing Record 25 of Set 6 | husavik
# Processing Record 26 of Set 6 | hofn
# Processing Record 27 of Set 6 | port hardy
# Processing Record 28 of Set 6 | cochrane
# Processing Record 29 of Set 6 | nyandoma
# Processing Record 30 of Set 6 | langsa
# Processing Record 31 of Set 6 | kudat
# Processing Record 32 of Set 6 | vagur
# Processing Record 33 of Set 6 | pribelskiy
# City not found. Skipping...
# Processing Record 34 of Set 6 | lompoc
# Processing Record 35 of Set 6 | poum
# Processing Record 36 of Set 6 | yazd
# Processing Record 37 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 38 of Set 6 | abu zabad
# Processing Record 39 of Set 6 | laredo
# Processing Record 40 of Set 6 | nizhnevartovsk
# Processing Record 41 of Set 6 | mount isa
# Processing Record 42 of Set 6 | queanbeyan
# Processing Record 43 of Set 6 | burica
# City not found. Skipping...
# Processing Record 44 of Set 6 | narsaq
# Processing Record 45 of Set 6 | flinders
# Processing Record 46 of Set 6 | westport
# Processing Record 47 of Set 6 | yumen
# Processing Record 48 of Set 6 | weinan
# Processing Record 49 of Set 6 | sisimiut
# Processing Record 50 of Set 6 | colwyn bay
# Processing Record 1 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 4 of Set 7 | qingdao
# Processing Record 5 of Set 7 | mujiayingzi
# Processing Record 6 of Set 7 | gerash
# Processing Record 7 of Set 7 | beaumont
# Processing Record 8 of Set 7 | batagay-alyta
# Processing Record 9 of Set 7 | namatanai
# Processing Record 10 of Set 7 | north bay
# Processing Record 11 of Set 7 | evensk
# Processing Record 12 of Set 7 | yantai
# Processing Record 13 of Set 7 | tagusao
# Processing Record 14 of Set 7 | ambilobe
# Processing Record 15 of Set 7 | linqiong
# Processing Record 16 of Set 7 | nabire
# Processing Record 17 of Set 7 | rio gallegos
# Processing Record 18 of Set 7 | beloha
# Processing Record 19 of Set 7 | margate
# Processing Record 20 of Set 7 | andrelandia
# Processing Record 21 of Set 7 | itoman
# Processing Record 22 of Set 7 | avera
# Processing Record 23 of Set 7 | xucheng
# Processing Record 24 of Set 7 | kendari
# Processing Record 25 of Set 7 | lazaro cardenas
# Processing Record 26 of Set 7 | isla mujeres
# Processing Record 27 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 7 | waitati
# Processing Record 29 of Set 7 | rudbar
# Processing Record 30 of Set 7 | kathmandu
# Processing Record 31 of Set 7 | male
# Processing Record 32 of Set 7 | kahului
# Processing Record 33 of Set 7 | coroisanmartin
# Processing Record 34 of Set 7 | nizwa
# Processing Record 35 of Set 7 | ovalle
# Processing Record 36 of Set 7 | la ronge
# Processing Record 37 of Set 7 | coihaique
# Processing Record 38 of Set 7 | bozoum
# Processing Record 39 of Set 7 | katangli
# Processing Record 40 of Set 7 | rigaud
# Processing Record 41 of Set 7 | thompson
# Processing Record 42 of Set 7 | hamilton
# Processing Record 43 of Set 7 | honghu
# Processing Record 44 of Set 7 | sandakan
# Processing Record 45 of Set 7 | nome
# Processing Record 46 of Set 7 | chernyy yar
# Processing Record 47 of Set 7 | tokur
# Processing Record 48 of Set 7 | pir
# Processing Record 49 of Set 7 | pevek
# Processing Record 50 of Set 7 | ulu tiram
# Processing Record 1 of Set 8 | fethiye
# Processing Record 2 of Set 8 | pacific grove
# Processing Record 3 of Set 8 | fukue
# Processing Record 4 of Set 8 | churapcha
# Processing Record 5 of Set 8 | kurilsk
# Processing Record 6 of Set 8 | palu
# Processing Record 7 of Set 8 | port-gentil
# Processing Record 8 of Set 8 | nioro
# Processing Record 9 of Set 8 | touros
# Processing Record 10 of Set 8 | nouakchott
# Processing Record 11 of Set 8 | malinovoye ozero
# Processing Record 12 of Set 8 | palmer
# Processing Record 13 of Set 8 | penzance
# Processing Record 14 of Set 8 | rantauprapat
# Processing Record 15 of Set 8 | kununurra
# Processing Record 16 of Set 8 | walvis bay
# Processing Record 17 of Set 8 | davila
# Processing Record 18 of Set 8 | carnarvon
# Processing Record 19 of Set 8 | wuwei
# Processing Record 20 of Set 8 | muros
# Processing Record 21 of Set 8 | tongchuan
# Processing Record 22 of Set 8 | ola
# Processing Record 23 of Set 8 | jiuquan
# Processing Record 24 of Set 8 | lagoa santa
# Processing Record 25 of Set 8 | camacha
# Processing Record 26 of Set 8 | abu kamal
# Processing Record 27 of Set 8 | kaffrine
# Processing Record 28 of Set 8 | cap malheureux
# Processing Record 29 of Set 8 | rexburg
# Processing Record 30 of Set 8 | key west
# Processing Record 31 of Set 8 | nuevo progreso
# Processing Record 32 of Set 8 | kaspiyskiy
# Processing Record 33 of Set 8 | mayskiy
# Processing Record 34 of Set 8 | sayat
# Processing Record 35 of Set 8 | ulladulla
# Processing Record 36 of Set 8 | lodja
# Processing Record 37 of Set 8 | praia da vitoria
# Processing Record 38 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 8 | sarab
# Processing Record 40 of Set 8 | biltine
# Processing Record 41 of Set 8 | oranjemund
# Processing Record 42 of Set 8 | lazi
# Processing Record 43 of Set 8 | port lincoln
# Processing Record 44 of Set 8 | torit
# Processing Record 45 of Set 8 | wanaka
# Processing Record 46 of Set 8 | nargana
# Processing Record 47 of Set 8 | tarko-sale
# Processing Record 48 of Set 8 | yei
# Processing Record 49 of Set 8 | henties bay
# Processing Record 50 of Set 8 | noumea
# Processing Record 1 of Set 9 | zemio
# Processing Record 2 of Set 9 | waw
# Processing Record 3 of Set 9 | chervishevo
# Processing Record 4 of Set 9 | storforshei
# Processing Record 5 of Set 9 | verkhoyansk
# Processing Record 6 of Set 9 | tairua
# Processing Record 7 of Set 9 | baykit
# Processing Record 8 of Set 9 | jieshi
# Processing Record 9 of Set 9 | tombouctou
# Processing Record 10 of Set 9 | saint-leu
# Processing Record 11 of Set 9 | miandrivazo
# Processing Record 12 of Set 9 | puerto ayacucho
# Processing Record 13 of Set 9 | pio xii
# Processing Record 14 of Set 9 | colac
# Processing Record 15 of Set 9 | cody
# Processing Record 16 of Set 9 | isangel
# Processing Record 17 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 9 | batocina
# Processing Record 19 of Set 9 | kontagora
# Processing Record 20 of Set 9 | san angelo
# Processing Record 21 of Set 9 | auki
# Processing Record 22 of Set 9 | adelaide
# Processing Record 23 of Set 9 | vostok
# Processing Record 24 of Set 9 | mitsamiouli
# Processing Record 25 of Set 9 | haines junction
# Processing Record 26 of Set 9 | wum
# Processing Record 27 of Set 9 | iberia
# Processing Record 28 of Set 9 | mozarlandia
# Processing Record 29 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 9 | florence
# Processing Record 31 of Set 9 | yatou
# Processing Record 32 of Set 9 | kambove
# Processing Record 33 of Set 9 | adjumani
# Processing Record 34 of Set 9 | alofi
# Processing Record 35 of Set 9 | akkudah
# City not found. Skipping...
# Processing Record 36 of Set 9 | koutsouras
# Processing Record 37 of Set 9 | gravdal
# Processing Record 38 of Set 9 | geraldton
# Processing Record 39 of Set 9 | armenis
# Processing Record 40 of Set 9 | askiz
# Processing Record 41 of Set 9 | amahai
# Processing Record 42 of Set 9 | daye
# Processing Record 43 of Set 9 | bowen
# Processing Record 44 of Set 9 | gat
# Processing Record 45 of Set 9 | keetmanshoop
# Processing Record 46 of Set 9 | sorland
# Processing Record 47 of Set 9 | khatanga
# Processing Record 48 of Set 9 | san jose
# Processing Record 49 of Set 9 | rio grande
# Processing Record 50 of Set 9 | petropavlovka
# Processing Record 1 of Set 10 | upernavik
# Processing Record 2 of Set 10 | sao raimundo das mangabeiras
# Processing Record 3 of Set 10 | san vicente
# Processing Record 4 of Set 10 | rawson
# Processing Record 5 of Set 10 | san luis potosi
# Processing Record 6 of Set 10 | gambela
# Processing Record 7 of Set 10 | ostrovnoy
# Processing Record 8 of Set 10 | dodge city
# Processing Record 9 of Set 10 | usinsk
# Processing Record 10 of Set 10 | ahuimanu
# Processing Record 11 of Set 10 | puerto escondido
# Processing Record 12 of Set 10 | zyryanka
# Processing Record 13 of Set 10 | siloam springs
# Processing Record 14 of Set 10 | disna
# Processing Record 15 of Set 10 | guerrero negro
# Processing Record 16 of Set 10 | urozhaynoye
# Processing Record 17 of Set 10 | giresun
# Processing Record 18 of Set 10 | mugumu
# Processing Record 19 of Set 10 | sibu
# Processing Record 20 of Set 10 | egvekinot
# Processing Record 21 of Set 10 | nantucket
# Processing Record 22 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 23 of Set 10 | matagami
# Processing Record 24 of Set 10 | samarai
# Processing Record 25 of Set 10 | port hawkesbury
# Processing Record 26 of Set 10 | dera bugti
# Processing Record 27 of Set 10 | manohar thana
# Processing Record 28 of Set 10 | elizabeth city
# Processing Record 29 of Set 10 | west bay
# Processing Record 30 of Set 10 | sangar
# Processing Record 31 of Set 10 | esmeraldas
# Processing Record 32 of Set 10 | mazatlan
# Processing Record 33 of Set 10 | huarmey
# Processing Record 34 of Set 10 | ilek
# Processing Record 35 of Set 10 | umea
# Processing Record 36 of Set 10 | tual
# Processing Record 37 of Set 10 | petersburg
# Processing Record 38 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 10 | atherton
# Processing Record 40 of Set 10 | tatawin
# Processing Record 41 of Set 10 | sombor
# Processing Record 42 of Set 10 | taurage
# Processing Record 43 of Set 10 | isla vista
# Processing Record 44 of Set 10 | yabrud
# Processing Record 45 of Set 10 | chyhyryn
# Processing Record 46 of Set 10 | honningsvag
# Processing Record 47 of Set 10 | matara
# Processing Record 48 of Set 10 | bay roberts
# Processing Record 49 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 11 | menongue
# Processing Record 2 of Set 11 | mazara del vallo
# Processing Record 3 of Set 11 | lorengau
# Processing Record 4 of Set 11 | puerto madryn
# Processing Record 5 of Set 11 | karratha
# Processing Record 6 of Set 11 | varnamo
# Processing Record 7 of Set 11 | rochegda
# Processing Record 8 of Set 11 | aksarka
# Processing Record 9 of Set 11 | grand gaube
# Processing Record 10 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 11 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 13 of Set 11 | coos bay
# Processing Record 14 of Set 11 | sabinas
# Processing Record 15 of Set 11 | ukiah
# Processing Record 16 of Set 11 | axim
# Processing Record 17 of Set 11 | hovd
# Processing Record 18 of Set 11 | thunder bay
# Processing Record 19 of Set 11 | luba
# Processing Record 20 of Set 11 | pangkalanbuun
# Processing Record 21 of Set 11 | aberdeen
# Processing Record 22 of Set 11 | salinopolis
# Processing Record 23 of Set 11 | piacabucu
# Processing Record 24 of Set 11 | vila velha
# Processing Record 25 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 11 | sale
# Processing Record 27 of Set 11 | karmana
# City not found. Skipping...
# Processing Record 28 of Set 11 | alyangula
# Processing Record 29 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 11 | teahupoo
# Processing Record 31 of Set 11 | severo-yeniseyskiy
# Processing Record 32 of Set 11 | high prairie
# Processing Record 33 of Set 11 | nahrin
# Processing Record 34 of Set 11 | prince albert
# Processing Record 35 of Set 11 | natal
# Processing Record 36 of Set 11 | coquimbo
# Processing Record 37 of Set 11 | ponta do sol
# Processing Record 38 of Set 11 | havoysund
# Processing Record 39 of Set 11 | belfast
# Processing Record 40 of Set 11 | balakhninskiy
# Processing Record 41 of Set 11 | dubbo
# Processing Record 42 of Set 11 | sabzevar
# Processing Record 43 of Set 11 | tumpat
# Processing Record 44 of Set 11 | arlit
# Processing Record 45 of Set 11 | shiyan
# Processing Record 46 of Set 11 | roald
# Processing Record 47 of Set 11 | quepos
# Processing Record 48 of Set 11 | abu samrah
# Processing Record 49 of Set 11 | polkowice
# Processing Record 50 of Set 11 | duminichi
# Processing Record 1 of Set 12 | leh
# Processing Record 2 of Set 12 | saint-louis
# Processing Record 3 of Set 12 | tucurui
# Processing Record 4 of Set 12 | constitucion
# Processing Record 5 of Set 12 | saint-francois
# Processing Record 6 of Set 12 | shingu
# Processing Record 7 of Set 12 | ciudad bolivar
# Processing Record 8 of Set 12 | talara
# Processing Record 9 of Set 12 | baindur
# Processing Record 10 of Set 12 | freeport
# Processing Record 11 of Set 12 | bartica
# Processing Record 12 of Set 12 | sungaipenuh
# Processing Record 13 of Set 12 | dossor
# Processing Record 14 of Set 12 | auch
# Processing Record 15 of Set 12 | inhambane
# Processing Record 16 of Set 12 | cotonou
# Processing Record 17 of Set 12 | vankleek hill
# Processing Record 18 of Set 12 | pulandian
# Processing Record 19 of Set 12 | malvern
# Processing Record 20 of Set 12 | san cristobal
# Processing Record 21 of Set 12 | avanigadda
# Processing Record 22 of Set 12 | tessalit
# Processing Record 23 of Set 12 | banda aceh
# Processing Record 24 of Set 12 | palasa
# Processing Record 25 of Set 12 | yerbogachen
# Processing Record 26 of Set 12 | tiarei
# Processing Record 27 of Set 12 | tsuruga
# Processing Record 28 of Set 12 | mecca
# Processing Record 29 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 30 of Set 12 | tura
# Processing Record 31 of Set 12 | emba
# Processing Record 32 of Set 12 | rovato
# Processing Record 33 of Set 12 | beringovskiy
# Processing Record 34 of Set 12 | atar
# Processing Record 35 of Set 12 | san ignacio
# Processing Record 36 of Set 12 | shar
# Processing Record 37 of Set 12 | tucuma
# Processing Record 38 of Set 12 | mehriz
# Processing Record 39 of Set 12 | buala
# Processing Record 40 of Set 12 | piracuruca
# Processing Record 41 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 42 of Set 12 | malanje
# Processing Record 43 of Set 12 | fowa
# Processing Record 44 of Set 12 | gari
# Processing Record 45 of Set 12 | kysyl-syr
# Processing Record 46 of Set 12 | ferme-neuve
# Processing Record 47 of Set 12 | fort morgan
# Processing Record 48 of Set 12 | asfi
# Processing Record 49 of Set 12 | tungor
# Processing Record 50 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 13 | moussoro
# Processing Record 2 of Set 13 | aswan
# Processing Record 3 of Set 13 | teknaf
# Processing Record 4 of Set 13 | marsa matruh
# Processing Record 5 of Set 13 | murakami
# Processing Record 6 of Set 13 | ratnagiri
# Processing Record 7 of Set 13 | shihezi
# Processing Record 8 of Set 13 | fort nelson
# Processing Record 9 of Set 13 | itarema
# Processing Record 10 of Set 13 | saint-georges
# Processing Record 11 of Set 13 | hanover
# Processing Record 12 of Set 13 | saint-pierre
# Processing Record 13 of Set 13 | cockburn town
# Processing Record 14 of Set 13 | mbandaka
# Processing Record 15 of Set 13 | det udom
# Processing Record 16 of Set 13 | amazar
# Processing Record 17 of Set 13 | shenjiamen
# Processing Record 18 of Set 13 | sao caitano
# Processing Record 19 of Set 13 | charagua
# Processing Record 20 of Set 13 | cochabamba
# Processing Record 21 of Set 13 | meadow lake
# Processing Record 22 of Set 13 | barcelona
# Processing Record 23 of Set 13 | siilinjarvi
# Processing Record 24 of Set 13 | jingdezhen
# Processing Record 25 of Set 13 | himora
# City not found. Skipping...
# Processing Record 26 of Set 13 | takoradi
# Processing Record 27 of Set 13 | le vauclin
# Processing Record 28 of Set 13 | yenagoa
# Processing Record 29 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 30 of Set 13 | sinnamary
# Processing Record 31 of Set 13 | bonavista
# Processing Record 32 of Set 13 | kotturu
# Processing Record 33 of Set 13 | port macquarie
# Processing Record 34 of Set 13 | gazojak
# Processing Record 35 of Set 13 | fez
# Processing Record 36 of Set 13 | zeerust
# Processing Record 37 of Set 13 | bela
# Processing Record 38 of Set 13 | kindersley
# Processing Record 39 of Set 13 | ilheus
# Processing Record 40 of Set 13 | dingle
# Processing Record 41 of Set 13 | kushmurun
# Processing Record 42 of Set 13 | ust-charyshskaya pristan
# Processing Record 43 of Set 13 | lethem
# Processing Record 44 of Set 13 | tocopilla
# Processing Record 45 of Set 13 | kozhva
# Processing Record 46 of Set 13 | xiaoweizhai
# Processing Record 47 of Set 13 | along
# Processing Record 48 of Set 13 | lieksa
# Processing Record 49 of Set 13 | batticaloa
# Processing Record 50 of Set 13 | nalut
# Processing Record 1 of Set 14 | hit
# Processing Record 2 of Set 14 | marzuq
# Processing Record 3 of Set 14 | dargaville
# Processing Record 4 of Set 14 | udachnyy
# Processing Record 5 of Set 14 | kestel
# Processing Record 6 of Set 14 | kananga
# Processing Record 7 of Set 14 | weiden
# Processing Record 8 of Set 14 | trelew
# Processing Record 9 of Set 14 | derzhavinsk
# Processing Record 10 of Set 14 | zabid
# Processing Record 11 of Set 14 | umm bab
# Processing Record 12 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 14 | jibuti
# Processing Record 14 of Set 14 | weligama
# Processing Record 15 of Set 14 | lokomotivnyy
# Processing Record 16 of Set 14 | kautokeino
# Processing Record 17 of Set 14 | sao luiz gonzaga
# Processing Record 18 of Set 14 | havre-saint-pierre
# Processing Record 19 of Set 14 | mangan
# Processing Record 20 of Set 14 | bonfim
# Processing Record 21 of Set 14 | blanquefort
# Processing Record 22 of Set 14 | nanortalik
# Processing Record 23 of Set 14 | kamoke
# Processing Record 24 of Set 14 | metro
# Processing Record 25 of Set 14 | chibombo
# Processing Record 26 of Set 14 | tukrah
# Processing Record 27 of Set 14 | pisco
# Processing Record 28 of Set 14 | prozor
# Processing Record 29 of Set 14 | puerto cabello
# Processing Record 30 of Set 14 | imbituba
# Processing Record 31 of Set 14 | lianzhou
# Processing Record 32 of Set 14 | macau
# Processing Record 33 of Set 14 | alpena
# Processing Record 34 of Set 14 | kyshtovka
# Processing Record 35 of Set 14 | macomb
# Processing Record 36 of Set 14 | navahrudak
# Processing Record 37 of Set 14 | chinsali
# Processing Record 38 of Set 14 | labuhan
# Processing Record 39 of Set 14 | strai
# Processing Record 40 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 14 | vestmanna
# Processing Record 43 of Set 14 | muzhi
# Processing Record 44 of Set 14 | waingapu
# Processing Record 45 of Set 14 | bilibino
# Processing Record 46 of Set 14 | gazimurskiy zavod
# Processing Record 47 of Set 14 | sarh
# Processing Record 48 of Set 14 | teluk nibung
# Processing Record 49 of Set 14 | kaseda
# Processing Record 50 of Set 14 | novoseleznevo
# Processing Record 1 of Set 15 | qandala
# Processing Record 2 of Set 15 | sao joao da barra
# Processing Record 3 of Set 15 | lunenburg
# Processing Record 4 of Set 15 | najran
# Processing Record 5 of Set 15 | baft
# Processing Record 6 of Set 15 | marquette
# Processing Record 7 of Set 15 | apomu
# Processing Record 8 of Set 15 | ambovombe
# Processing Record 9 of Set 15 | dmitrovsk-orlovskiy
# Processing Record 10 of Set 15 | porteirinha
# Processing Record 11 of Set 15 | te anau
# Processing Record 12 of Set 15 | beian
# Processing Record 13 of Set 15 | pocao de pedras
# Processing Record 14 of Set 15 | maniitsoq
# Processing Record 15 of Set 15 | qunduz
# Processing Record 16 of Set 15 | ereymentau
# Processing Record 17 of Set 15 | nsanje
# Processing Record 18 of Set 15 | vryburg
# Processing Record 19 of Set 15 | varzelandia
# Processing Record 20 of Set 15 | port charlotte
# Processing Record 21 of Set 15 | iisalmi
# Processing Record 22 of Set 15 | bayan
# Processing Record 23 of Set 15 | teguise
# Processing Record 24 of Set 15 | nouadhibou
# Processing Record 25 of Set 15 | bulungu
# Processing Record 26 of Set 15 | hoi an
# Processing Record 27 of Set 15 | ust-kulom
# Processing Record 28 of Set 15 | urdoma
# Processing Record 29 of Set 15 | altus
# Processing Record 30 of Set 15 | goaigoaza
# City not found. Skipping...
# Processing Record 31 of Set 15 | ugoofaaru
# Processing Record 32 of Set 15 | mpanda
# Processing Record 33 of Set 15 | hilversum
# Processing Record 34 of Set 15 | fenoarivo
# Processing Record 35 of Set 15 | samarkand
# Processing Record 36 of Set 15 | barbastro
# Processing Record 37 of Set 15 | nago
# Processing Record 38 of Set 15 | aksu
# Processing Record 39 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 15 | ous
# Processing Record 41 of Set 15 | zhitikara
# City not found. Skipping...
# Processing Record 42 of Set 15 | acajutla
# Processing Record 43 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 44 of Set 15 | emmett
# Processing Record 45 of Set 15 | labrea
# Processing Record 46 of Set 15 | mao
# Processing Record 47 of Set 15 | daru
# Processing Record 48 of Set 15 | manta
# Processing Record 49 of Set 15 | padang
# Processing Record 50 of Set 15 | hof
# Processing Record 1 of Set 16 | bodden town
# Processing Record 2 of Set 16 | tevriz
# Processing Record 3 of Set 16 | talaya
# Processing Record 4 of Set 16 | quixada
# Processing Record 5 of Set 16 | belaya gora
# Processing Record 6 of Set 16 | gondanglegi
# Processing Record 7 of Set 16 | labuan
# Processing Record 8 of Set 16 | chernogolovka
# Processing Record 9 of Set 16 | lotoshino
# Processing Record 10 of Set 16 | karabuk
# Processing Record 11 of Set 16 | imeni poliny osipenko
# Processing Record 12 of Set 16 | haimen
# Processing Record 13 of Set 16 | ashland
# Processing Record 14 of Set 16 | uaua
# Processing Record 15 of Set 16 | el badari
# City not found. Skipping...
# Processing Record 16 of Set 16 | chirongui
# Processing Record 17 of Set 16 | maragogi
# Processing Record 18 of Set 16 | christchurch
# Processing Record 19 of Set 16 | lakatoro
# Processing Record 20 of Set 16 | manacapuru
# Processing Record 21 of Set 16 | azul
# Processing Record 22 of Set 16 | phuket
# Processing Record 23 of Set 16 | colesberg
# Processing Record 24 of Set 16 | odweyne
# Processing Record 25 of Set 16 | mogadishu
# Processing Record 26 of Set 16 | macas
# Processing Record 27 of Set 16 | kadipaten
# Processing Record 28 of Set 16 | kannangad
# Processing Record 29 of Set 16 | belyy yar
# Processing Record 30 of Set 16 | zhuanghe
# Processing Record 31 of Set 16 | bukama
# Processing Record 32 of Set 16 | ust-tsilma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 719

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hilo      US  19.7297 -155.0900     75.27        97         100
# 1     Busselton      AU -33.6500  115.3333     60.91        67          33
# 2      Hermanus      ZA -34.4187   19.2345     51.80        66          97
# 3         Kapaa      US  22.0752 -159.3190     73.72        87         100
# 4   Provideniya      RU  64.3833 -173.3000     35.40        96          99
# 5       Ushuaia      AR -54.8000  -68.3000     40.62        81           0
# 6        Atuona      PF  -9.8000 -139.0333     77.27        73          39
# 7     La Ciotat      FR  43.1748    5.6045     91.80        75          16
# 8  Bahia Blanca      AR -38.7196  -62.2724     58.78        41         100
# 9         Vaini      TO -21.2000 -175.2000     69.96       100          20
#
#    Wind Speed Current Description
# 0        6.91          light rain
# 1       11.43    scattered clouds
# 2       17.56          light rain
# 3       17.27     overcast clouds
# 4        5.57          light rain
# 5        4.61           clear sky
# 6       19.80    scattered clouds
# 7        9.13          few clouds
# 8       11.68     overcast clouds
# 9        3.44          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
